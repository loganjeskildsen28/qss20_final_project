# %%
## Imports from activity 6: apis_blank
import pandas as pd
import numpy as np
import re
import requests
import yaml
import os

## Imports for wikipedia pulls
import pywikibot as pw
import time
pw.config.user_agent = 'EskildsenLogan research project (logan.j.eskildsen.28@dartmouth.edu) Pywikibot/11.6.0'

## Imports for test visualization, if needed
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy.optimize import curve_fit

## Imports for google search trends
# !pip install pytrends
from pytrends.request import TrendReq

## Set font parameters, if needed
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Times New Roman"]


## Repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# Collecting pytrends
#   Downloading pytrends-4.9.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.0 in c:\users\logan\anaconda3\lib\site-packages (from pytrends) (2.32.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\logan\anaconda3\lib\site-packages (from pytrends) (2.3.3)
# Requirement already satisfied: lxml in c:\users\logan\anaconda3\lib\site-packages (from pytrends) (5.3.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\logan\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\logan\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\logan\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\logan\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\logan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\logan\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\logan\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\logan\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\logan\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2026.6.17)
# Downloading pytrends-4.9.2-py3-none-any.whl (15 kB)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.2

# %%
## Part 1: creates foundational dataframe for project, scraped from google searches

## List of countries U.S. has played since 2014. Include year, match outcome, match score, match date, match type.
country_list = ["Ghana", "Portugal", "Germany", "Belgium",
                "Wales", "England", "Iran", "Netherlands", 
                "Paraguay", "Australia", "Turkey", "Bosnia_and_Herzegovina", "Belgium"]

year_played = [2014, 2014, 2014, 2014,
               2022, 2022, 2022, 2022, 
               2026, 2026, 2026, 2026, 2026]

match_outcome = ["win", "draw", "loss", "loss",
                 "draw", "draw", "win", "loss", 
                 "win", "win", "loss", "win", "loss"]

match_score = ["2-1", "2-2", "0-1", "1-2",
              "1-1", "0-0", "1-0", "1-3",
              "4-1", "2-0", "2-3", "2-0", "1-4"]

match_date = ["20140614", "20140622", "20140626", "20140701",
             "20221121", "20221125", "20221129", "20221203",
             "20260612", "20260619", "20260625", "20260701", "20260706"]

match_type = ["group", "group", "group", "knockout",
            "group", "group", "group", "knockout",
            "group", "group", "group", "knockout", "knockout"]

## Create simple dataframe for visualization

basic_info = pd.DataFrame({"country": country_list, "year played": year_played, 
                           "match date": match_date, "outcome": match_outcome, "match type": match_type, "score": match_score,})
basic_info

## Now store the data as a csv to call later so I do not have to rerun code.
basic_info.to_csv('./data/basic_info.csv', index=False)
# Out:
#                    country  year played match date outcome match type score
# 0                    Ghana         2014   20140614     win      group   2-1
# 1                 Portugal         2014   20140622    draw      group   2-2
# 2                  Germany         2014   20140626    loss      group   0-1
# 3                  Belgium         2014   20140701    loss   knockout   1-2
# 4                    Wales         2022   20221121    draw      group   1-1
# 5                  England         2022   20221125    draw      group   0-0
# 6                     Iran         2022   20221129     win      group   1-0
# 7              Netherlands         2022   20221203    loss   knockout   1-3
# 8                 Paraguay         2026   20260612     win      group   4-1
# 9                Australia         2026   20260619     win      group   2-0
# 10                  Turkey         2026   20260625    loss      group   2-3
# 11  Bosnia_and_Herzegovina         2026   20260701     win   knockout   2-0
# 12                 Belgium         2026   20260706    loss   knockout   1-4

# %%
## Part 2: Access popular article data
## Use pywikibot library to extract main Wiki subcategories for each country category. List of countries defined in the dataframe

site = pw.Site("en", "wikipedia")

## Empty list to store data later.

subcat_data = []

## User-defined function that iterates over the country column in basic_info df, gets all data on subcategories for each country.
def get_wiki_subcategories(countries):
    ## Get each category associated with country, perform a recursive loop
    for cat_name in countries:
        
        cat = pw.Category(site, cat_name)

        # Use try-except to get information on pages per subcategory
        for subcat in cat.subcategories():

            try:

                all_info = subcat.categoryinfo

                num_articles = all_info.get('pages', 0)

                cat_title = subcat.title()

                subcat_data.append({
                    "country": cat_name,
                    "subcategory_title": cat_title,
                    "article_count": num_articles
                })
                ## Need time.sleep() because I kept getting 429 errors, making too many requests.
                time.sleep(2)

            except KeyError:

                 print(f"{subcat.title()}: 0 articles (or info unavailable)")

## call function, use to_list() method
get_wiki_subcategories(basic_info["country"])

subcat_df = pd.DataFrame(subcat_data)

subcat_df
# Out:
#      country                           subcategory_title  article_count
# 0      Ghana                Category:Ghana-related lists              8
# 1      Ghana  Category:Buildings and structures in Ghana              4
# 2      Ghana                   Category:Culture of Ghana             54
# 3      Ghana                   Category:Economy of Ghana             26
# 4      Ghana                 Category:Education in Ghana             38
# ..       ...                                         ...            ...
# 222  Belgium                     Category:Belgian people              2
# 223  Belgium                Category:Politics of Belgium             40
# 224  Belgium                 Category:Society of Belgium             12
# 225  Belgium                  Category:Images of Belgium              1
# 226  Belgium                      Category:Belgium stubs            215
#
# [227 rows x 3 columns]

# %%
## Removes stubs from subcategories since it confounds data
subcat_df_final = subcat_df[~subcat_df['subcategory_title'].str.contains('stubs', na=False)].copy()

## Now eliminate duplicates from repeat matches (Belgium)
subcat_df_final = subcat_df_final.drop_duplicates().copy()

## Format the data better by removing "Category:" using the regex skills we learned in class
subcat_df_final["subcategory_title_fixed"] = subcat_df_final["subcategory_title"].str.replace('^Category:', '', regex=True)

## Now sort by top 4 article count by subcategory for each country
subcat_df_final = (
    subcat_df_final.sort_values(by=["country", "article_count"], ascending=[True, False])
    .groupby('country')
    .head(4)
    .reset_index(drop=True)
    .copy()
)

## Now display presentable dataframe
subcat_df_data = subcat_df_final[["country", "subcategory_title_fixed", "subcategory_title", "article_count"]]

subcat_df_data

subcat_df_data.to_csv("./data/subcategory_data.csv", index=False)
# Out:
#                    country             subcategory_title_fixed  \
# 0                Australia                Culture of Australia
# 1                Australia               Politics of Australia
# 2                Australia              Education in Australia
# 3                Australia             Government of Australia
# 4                  Belgium                  Culture of Belgium
# 5                  Belgium                 Politics of Belgium
# 6                  Belgium               Government of Belgium
# 7                  Belgium                  Economy of Belgium
# 8   Bosnia_and_Herzegovina   Culture of Bosnia and Herzegovina
# 9   Bosnia_and_Herzegovina    Bosnia and Herzegovina templates
# 10  Bosnia_and_Herzegovina   Economy of Bosnia and Herzegovina
# 11  Bosnia_and_Herzegovina  Politics of Bosnia and Herzegovina
# 12                 England                  Culture of England
# 13                 England                  Housing in England
# 14                 England                 Politics of England
# 15                 England                Geography of England
# 16                 Germany                  Culture of Germany
# 17                 Germany                Education in Germany
# 18                 Germany                 Politics of Germany
# 19                 Germany                  Economy of Germany
# 20                   Ghana                   Politics of Ghana
# 21                   Ghana                 Government of Ghana
# 22                   Ghana                    Culture of Ghana
# 23                   Ghana                  Education in Ghana
# 24                    Iran                     Economy of Iran
# 25                    Iran                     Culture of Iran
# 26                    Iran                    Politics of Iran
# 27                    Iran                  Government of Iran
# 28             Netherlands          Culture of the Netherlands
# 29             Netherlands       Government of the Netherlands
# 30             Netherlands        Education in the Netherlands
# 31             Netherlands         Politics of the Netherlands
# 32                Paraguay              Government of Paraguay
# 33                Paraguay                 Economy of Paraguay
# 34                Paraguay                Politics of Paraguay
# 35                Paraguay                 Culture of Paraguay
# 36                Portugal                Politics of Portugal
# 37                Portugal              Government of Portugal
# 38                Portugal                 Culture of Portugal
# 39                Portugal                 Economy of Portugal
# 40                  Turkey                   Culture of Turkey
# 41                  Turkey                  Politics of Turkey
# 42                  Turkey                 Education in Turkey
# 43                  Turkey                Government of Turkey
# 44                   Wales                    History of Wales
# 45                   Wales                      Welsh language
# 46                   Wales                   Politics of Wales
# 47                   Wales                    Culture of Wales
#
#                               subcategory_title  article_count
# 0                 Category:Culture of Australia             70
# 1                Category:Politics of Australia             57
# 2               Category:Education in Australia             53
# 3              Category:Government of Australia             37
# 4                   Category:Culture of Belgium             41
# 5                  Category:Politics of Belgium             40
# 6                Category:Government of Belgium             35
# 7                   Category:Economy of Belgium             22
# 8    Category:Culture of Bosnia and Herzegovina             46
# 9     Category:Bosnia and Herzegovina templates             40
# 10   Category:Economy of Bosnia and Herzegovina             25
# 11  Category:Politics of Bosnia and Herzegovina             25
# 12                  Category:Culture of England             74
# 13                  Category:Housing in England             30
# 14                 Category:Politics of England             28
# 15                Category:Geography of England             26
# 16                  Category:Culture of Germany             70
# 17                Category:Education in Germany             65
# 18                 Category:Politics of Germany             39
# 19                  Category:Economy of Germany             30
# 20                   Category:Politics of Ghana             69
# 21                 Category:Government of Ghana             65
# 22                    Category:Culture of Ghana             54
# 23                  Category:Education in Ghana             38
# 24                     Category:Economy of Iran             90
# 25                     Category:Culture of Iran             83
# 26                    Category:Politics of Iran             81
# 27                  Category:Government of Iran             43
# 28          Category:Culture of the Netherlands             73
# 29       Category:Government of the Netherlands             37
# 30        Category:Education in the Netherlands             36
# 31         Category:Politics of the Netherlands             25
# 32              Category:Government of Paraguay             19
# 33                 Category:Economy of Paraguay             12
# 34                Category:Politics of Paraguay             12
# 35                 Category:Culture of Paraguay              9
# 36                Category:Politics of Portugal             46
# 37              Category:Government of Portugal             39
# 38                 Category:Culture of Portugal             28
# 39                 Category:Economy of Portugal             13
# 40                   Category:Culture of Turkey             73
# 41                  Category:Politics of Turkey             59
# 42                 Category:Education in Turkey             27
# 43                Category:Government of Turkey             25
# 44                    Category:History of Wales             98
# 45                      Category:Welsh language             78
# 46                   Category:Politics of Wales             65
# 47                    Category:Culture of Wales             61

# %%
## Define a function that pulls four most popular articles from each country by ranking via pageviews. First, outline dates
start_date_2014 = 20140601
end_date_2014 = 20140730

start_date_2022 = 20221101
end_date_2022 = 20221231

start_date_2026 = 20260601
end_date_2026 = 20260730

## Create dictionary of start and end dates for each country
cup_windows = {
    'Australia': [(start_date_2026, end_date_2026)],
    'Belgium': [(start_date_2014, end_date_2014), (start_date_2026, end_date_2026)],  # or handle 2014/2022 separately if kept distinct
    'Bosnia_and_Herzegovina': [(start_date_2026, end_date_2026)],
    'England': [(start_date_2022, end_date_2022)],
    'Germany': [(start_date_2014, end_date_2014)],
    'Ghana': [(start_date_2014, end_date_2014)],
    'Iran': [(start_date_2022, end_date_2022)],
    'Netherlands': [(start_date_2022, end_date_2022)],
    'Paraguay': [(start_date_2026, end_date_2026)],
    'Portugal': [(start_date_2014, end_date_2014)],
    'Turkey': [(start_date_2026, end_date_2026)],
    'Wales': [(start_date_2022, end_date_2022)],
}

# %%
## Now pull article data for each subcategory, long run time.
article_rows = []

def articles_for_subcats(subcat_df_final):
    for _, row in subcat_df_final.iterrows():
        country = row['country']
        subcat_title = row['subcategory_title'] ## pywikibot needs this
        subcat = pw.Category(site, subcat_title)

        ## Routinely getting errors from the pull, use the try, except logic to resolve issues
        try:
            for page in subcat.articles():
                article_rows.append({
                    'country': country,
                    'subcategory_title_fixed': row['subcategory_title_fixed'],
                    'article_title': page.title()
                })
            time.sleep(4)  
        except Exception as e:
            print(f"Error pulling articles from {subcat_title}: {e}")

articles_for_subcats(subcat_df_final)
articles_df = pd.DataFrame(article_rows)
# Out:
# WARNING: Http response status 429
# WARNING: Non-JSON response received from server wikipedia:en for url
# https://en.wikipedia.org/w/api.php
# The server may be down.
# Status code: 429
# User agent: /ipykernel_launcher (wikipedia:en) Pywikibot/11.6.0 (-1 (unknown)) Python/3.13.9.final.0 requests/2.32.5
#
# The text message is:
# You are making too many requests to the API.
# Please follow the best practices at .
# If you are unsure how to get the access you need, contact .
# request-id: f2ddb36b-c9fc-4533-a2d3-1f0f763579bd
#
# Set gcmlimit = ['250']
# WARNING: Waiting 5.0 seconds before retrying.
# Sleeping for 4.9 seconds, 2026-08-18 19:01:55
# WARNING: Http response status 429
# WARNING: Non-JSON response received from server wikipedia:en for url
# https://en.wikipedia.org/w/api.php
# The server may be down.
# Status code: 429
# User agent: /ipykernel_launcher (wikipedia:en) Pywikibot/11.6.0 (-1 (unknown)) Python/3.13.9.final.0 requests/2.32.5
#
# The text message is:
# You are making too many requests to the API.
# Please follow the best practices at .
# If you are unsure how to get the access you need, contact .
# request-id: 9512e0e8-b938-46ce-9e13-cd1b3b7cf19c
#
# Set gcmlimit = ['250']
# WARNING: Waiting 5.0 seconds before retrying.
# Sleeping for 14.0 seconds, 2026-08-18 19:02:47
# WARNING: Http response status 429
# WARNING: Non-JSON response received from server wikipedia:en for url
# https://en.wikipedia.org/w/api.php
# The server may be down.
# Status code: 429
# User agent: /ipykernel_launcher (wikipedia:en) Pywikibot/11.6.0 (-1 (unknown)) Python/3.13.9.final.0 requests/2.32.5
#
# The text message is:
# You are making too many requests to the API.
# Please follow the best practices at .
# If you are unsure how to get the access you need, contact .
# request-id: df6af4ee-b1ef-4f59-a1fe-12e06ca217ae
#
# Set gcmlimit = ['250']
# WARNING: Waiting 5.0 seconds before retrying.
# Sleeping for 13.0 seconds, 2026-08-18 19:03:47
# WARNING: Http response status 429
# WARNING: Non-JSON response received from server wikipedia:en for url
# https://en.wikipedia.org/w/api.php
# The server may be down.
# Status code: 429
# User agent: /ipykernel_launcher (wikipedia:en) Pywikibot/11.6.0 (-1 (unknown)) Python/3.13.9.final.0 requests/2.32.5
#
# The text message is:
# You are making too many requests to the API.
# Please follow the best practices at .
# If you are unsure how to get the access you need, contact .
# request-id: 65cfc614-fb8c-4f56-a40b-f6c4d53b4a9e
#
# Set gcmlimit = ['250']
# WARNING: Waiting 5.0 seconds before retrying.
# Sleeping for 13.0 seconds, 2026-08-18 19:04:47

# %%
## Now define a user-generated function to call daily article views for the cup windows we defined earlier
## The function calls upon the four most popular subcategories.

headers = {
    'User-Agent': 'EskildsenLogan research project (logan.j.eskildsen.28@dartmouth.edu)'
}

def get_daily_pageviews(articles_df, cup_windows, headers):
    all_daily_records = []

    ## Define cleaner variables
    for _, row in articles_df.iterrows():
        country = row['country']
        subcat = row['subcategory_title_fixed']
        article = row['article_title'].replace(' ', '_')
        
        if country not in cup_windows:
            print(f"No date range defined for {country}, skipping {article}")
            continue
        start_date, end_date = cup_windows[country]
        
        pv_query = (
            'https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/'
            f'en.wikipedia.org/all-access/all-agents/{article}/daily/{start_date}/{end_date}'
        )
        
        try:
            pv_resp = requests.get(pv_query, headers=headers)
            if pv_resp.status_code == 200:
                items = pv_resp.json().get('items', [])
                for item in items:
                    all_daily_records.append({
                        'country': country,
                        'subcategory_title_fixed': subcat,
                        'article_title': article,
                        'date': item['timestamp'][:8],  # YYYYMMDD
                        'views': item.get('views', 0)
                    })
            else:
                # article had no pageview data in this window (common for 404s)
                all_daily_records.append({
                    'country': country,
                    'subcategory_title_fixed': subcat,
                    'article_title': article,
                    'date': None,
                    'views': 0
                })
        except Exception as e:
            print(f"Error pulling pageviews for {article}: {e}")
        
        time.sleep(0.2)
    
    return pd.DataFrame(all_daily_records)

daily_views_df = get_daily_pageviews(articles_df, cup_windows, headers)
daily_views_df
# Out:
#          country subcategory_title_fixed         article_title      date  \
# 0      Australia    Culture of Australia  Culture_of_Australia  20260601
# 1      Australia    Culture of Australia  Culture_of_Australia  20260602
# 2      Australia    Culture of Australia  Culture_of_Australia  20260603
# 3      Australia    Culture of Australia  Culture_of_Australia  20260604
# 4      Australia    Culture of Australia  Culture_of_Australia  20260605
# ...          ...                     ...                   ...       ...
# 88077      Wales        Culture of Wales        Welsh_toponymy  20221227
# 88078      Wales        Culture of Wales        Welsh_toponymy  20221228
# 88079      Wales        Culture of Wales        Welsh_toponymy  20221229
# 88080      Wales        Culture of Wales        Welsh_toponymy  20221230
# 88081      Wales        Culture of Wales        Welsh_toponymy  20221231
#
#        views
# 0        354
# 1        341
# 2        427
# 3        371
# 4        331
# ...      ...
# 88077     40
# 88078     35
# 88079     44
# 88080     33
# 88081     51
#
# [88082 rows x 5 columns]

# %%
## Now visualize articles_df and create a user-defined function to extract the most popular article from
## each of the four most popular categories
articles_df

## Convert daily views dataframe to a csv callable later
daily_views_df.to_csv('./data/daily_wikipedia_views_all.csv', index=False)
# Out:
#         country subcategory_title_fixed                       article_title
# 0     Australia    Culture of Australia                Culture of Australia
# 1     Australia    Culture of Australia                               AC/DC
# 2     Australia    Culture of Australia                              Akubra
# 3     Australia    Culture of Australia                        Anzac spirit
# 4     Australia    Culture of Australia  Australian citizenship affirmation
# ...         ...                     ...                                 ...
# 2211      Wales        Culture of Wales                  Welsh Morris dance
# 2212      Wales        Culture of Wales                     Welsh stepdance
# 2213      Wales        Culture of Wales                       Welsh studies
# 2214      Wales        Culture of Wales                      Welsh surnames
# 2215      Wales        Culture of Wales                      Welsh toponymy
#
# [2216 rows x 3 columns]

# %%
## Track top pageviews via the highest mean over the window.

## First calculate mean views per article over each cup window.
mean_views = (
    daily_views_df.groupby(['country', 'subcategory_title_fixed', 'article_title'])['views']
    .mean()
    .reset_index()
    .rename(columns={'views': 'mean_views'})
)

## Display df
mean_views

## Now use sort_values() method and .head(1) to find the top article spot
top_article_per_subcat = (
    mean_views.sort_values('mean_views', ascending=False)
    .groupby(['country', 'subcategory_title_fixed'])
    .head(1)
    .reset_index(drop=True)
)

top_article_per_subcat

top_article_per_subcat.to_csv('./data/top_articles_list.csv', index=False)
# Out:
#         country subcategory_title_fixed                       article_title  \
# 0     Australia    Culture of Australia                               AC/DC
# 1     Australia    Culture of Australia                              Akubra
# 2     Australia    Culture of Australia                        Anzac_spirit
# 3     Australia    Culture of Australia   Australian_Journal_of_Linguistics
# 4     Australia    Culture of Australia  Australian_citizenship_affirmation
# ...         ...                     ...                                 ...
# 2211      Wales          Welsh language                      Welsh_toponymy
# 2212      Wales          Welsh language                   William_Salesbury
# 2213      Wales          Welsh language                               Wlpan
# 2214      Wales          Welsh language                       Y_Fro_Gymraeg
# 2215      Wales          Welsh language                         Y_with_loop
#
#       mean_views
# 0       0.000000
# 1     124.816667
# 2      56.283333
# 3       4.706897
# 4       6.866667
# ...          ...
# 2211   45.836066
# 2212   16.754098
# 2213    5.016667
# 2214   27.295082
# 2215    3.950000
#
# [2216 rows x 4 columns]
#                    country             subcategory_title_fixed  \
# 0                  England                  Culture of England
# 1              Netherlands          Culture of the Netherlands
# 2                     Iran                     Culture of Iran
# 3                    Wales                      Welsh language
# 4                Australia                Culture of Australia
# 5                    Wales                    Culture of Wales
# 6                  England                 Politics of England
# 7                     Iran                    Politics of Iran
# 8                  Belgium                  Culture of Belgium
# 9                     Iran                     Economy of Iran
# 10                  Turkey                   Culture of Turkey
# 11                  Turkey                  Politics of Turkey
# 12               Australia              Education in Australia
# 13               Australia               Politics of Australia
# 14                 England                Geography of England
# 15                Paraguay                 Economy of Paraguay
# 16                   Wales                    History of Wales
# 17                   Wales                   Politics of Wales
# 18                  Turkey                Government of Turkey
# 19                 Belgium               Government of Belgium
# 20             Netherlands        Education in the Netherlands
# 21                    Iran                  Government of Iran
# 22  Bosnia_and_Herzegovina  Politics of Bosnia and Herzegovina
# 23             Netherlands       Government of the Netherlands
# 24               Australia             Government of Australia
# 25                Paraguay                Politics of Paraguay
# 26                 Belgium                  Economy of Belgium
# 27             Netherlands         Politics of the Netherlands
# 28  Bosnia_and_Herzegovina   Economy of Bosnia and Herzegovina
# 29                Paraguay              Government of Paraguay
# 30  Bosnia_and_Herzegovina   Culture of Bosnia and Herzegovina
# 31                 Belgium                 Politics of Belgium
# 32                  Turkey                 Education in Turkey
# 33                Paraguay                 Culture of Paraguay
# 34                 England                  Housing in England
# 35  Bosnia_and_Herzegovina    Bosnia and Herzegovina templates
# 36                 Germany                  Economy of Germany
# 37                 Germany                Education in Germany
# 38                 Germany                 Politics of Germany
# 39                 Germany                  Culture of Germany
# 40                   Ghana                    Culture of Ghana
# 41                   Ghana                 Government of Ghana
# 42                   Ghana                   Politics of Ghana
# 43                   Ghana                  Education in Ghana
# 44                Portugal                Politics of Portugal
# 45                Portugal              Government of Portugal
# 46                Portugal                 Economy of Portugal
# 47                Portugal                 Culture of Portugal
#
#                                        article_title    mean_views
# 0                                        The_Beatles  16766.098361
# 1                                        Sinterklaas   4660.983607
# 2                                   Persian_language   4656.245902
# 3                                     Welsh_language   3820.704918
# 4                                  Bluey_(TV_series)   2951.150000
# 5                                          Mari_Lwyd   2132.213115
# 6                                Counties_of_England   1808.131148
# 7                             Supreme_Leader_of_Iran   1721.081967
# 8                           The_Adventures_of_Tintin   1652.333333
# 9                                    Economy_of_Iran   1141.163934
# 10                                    Nazar_(amulet)    833.666667
# 11                 Grand_National_Assembly_of_Turkey    765.716667
# 12                                  Graduate_diploma    708.066667
# 13               Australian_House_of_Representatives    705.116667
# 14                                  Northern_England    656.770492
# 15                                          Mercosur    648.366667
# 16                                  History_of_Wales    579.901639
# 17                                            Senedd    521.459016
# 18                               President_of_Turkey    508.783333
# 19                                    Flemish_Region    498.250000
# 20                      Education_in_the_Netherlands    480.442623
# 21                                  Politics_of_Iran    470.098361
# 22    High_Representative_for_Bosnia_and_Herzegovina    441.250000
# 23                        Capital_of_the_Netherlands    365.622951
# 24                             Australian_Government    364.550000
# 25                             President_of_Paraguay    296.550000
# 26                                Economy_of_Belgium    258.316667
# 27                       Politics_of_the_Netherlands    242.704918
# 28                 Economy_of_Bosnia_and_Herzegovina    221.716667
# 29                   Chamber_of_Deputies_of_Paraguay    206.500000
# 30                           The_Bridge_on_the_Drina    187.933333
# 31                 Hypothetical_partition_of_Belgium    180.550000
# 32                               Education_in_Turkey     88.083333
# 33                               Culture_of_Paraguay     77.133333
# 34                                            BedZED     71.114754
# 35                  Template:Campaignbox_Bosnian_War      7.283333
# 36  Federal_Ministry_for_Economic_Affairs_and_Energy      0.000000
# 37                                          Fachwirt      0.000000
# 38                        District_council_(Germany)      0.000000
# 39                                          Eurogame      0.000000
# 40                                            Gambei      0.000000
# 41                       National_Liberation_Council      0.000000
# 42                             Human_rights_in_Ghana      0.000000
# 43                        Zabzugu_Senior_High_School      0.000000
# 44                                         Freguesia      0.000000
# 45              Superior_Council_of_National_Defence      0.000000
# 46                               Housing_in_Portugal      0.000000
# 47                       Public_holidays_in_Portugal      0.000000

# %%
## Now get data on each country's main page views during each window

def get_country_daily_pageviews(cup_windows, headers):
    country_daily_records = []
    
    for country, windows in cup_windows.items():
        
        for start_date, end_date in windows:
            pv_query = (
                'https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/'
                f'en.wikipedia.org/all-access/all-agents/{country}/daily/{start_date}/{end_date}'
            )
            
            try:
                pv_resp = requests.get(pv_query, headers=headers)
                if pv_resp.status_code == 200:
                    items = pv_resp.json().get('items', [])
                    for item in items:
                        country_daily_records.append({
                            'country': country,
                            'article_title': country,
                            'date': item['timestamp'][:8],
                            'views': item.get('views', 0)
                        })
                else:
                    country_daily_records.append({
                        'country': country,
                        'article_title': country,
                        'date': None,
                        'views': 0
                    })
            except Exception as e:
                print(f"Error pulling pageviews for {country}: {e}")
            
            time.sleep(0.2)
    
    return pd.DataFrame(country_daily_records)

country_daily_views_df = get_country_daily_pageviews(cup_windows, headers)
country_daily_views_df

country_daily_views_df.to_csv('./data/country_daily_views.csv', index=False)
# Out:
#        country article_title      date  views
# 0    Australia     Australia  20260601  14059
# 1    Australia     Australia  20260602  14863
# 2    Australia     Australia  20260603  14307
# 3    Australia     Australia  20260604  15085
# 4    Australia     Australia  20260605  17752
# ..         ...           ...       ...    ...
# 543      Wales         Wales  20221227   6694
# 544      Wales         Wales  20221228   6289
# 545      Wales         Wales  20221229   6492
# 546      Wales         Wales  20221230   6167
# 547      Wales         Wales  20221231   5998
#
# [548 rows x 4 columns]

# %%
## Part 3: Access census data

## Define census api key, please don't take mine!
census_api = '9fdf899b3427f195717633b957799dd41ae17fdf'
census_api_key = os.environ.get('CENSUS_API_KEY', f'{census_api}')

# %%
## I don't feel like writing a function to call for specific country codes within the B05006 table. I will pull these manually instead 
## for the 2022 and 2024 sets

countries_2022 = ['Wales', 'England', 'Iran', 'Netherlands']
codes_2022 = ['B05006_009E', 'B05006_010E', 'B05006_061E', 'B05006_018E']

## 2024 is the most recent available census data, reasonable to take given migration patterns on the order of 5-10 years+.
countries_2024 = ['Paraguay', 'Australia', 'Turkey', 'Bosnia_and_Herzegovina', 'Belgium']
codes_2024 = ['B05006_175E', 'B05006_132E', 'B05006_090E', 'B05006_031E', 'B05006_015E']

census_table_2022 = pd.DataFrame({"country": countries_2022, "code": codes_2022})
census_table_2024 = pd.DataFrame({"country": countries_2024, "code": codes_2024})

census_table_2022
census_table_2024
# Out:
#        country         code
# 0        Wales  B05006_009E
# 1      England  B05006_010E
# 2         Iran  B05006_061E
# 3  Netherlands  B05006_018E
#                   country         code
# 0                Paraguay  B05006_175E
# 1               Australia  B05006_132E
# 2                  Turkey  B05006_090E
# 3  Bosnia_and_Herzegovina  B05006_031E
# 4                 Belgium  B05006_015E

# %%
## Now pull diaspora data. We just want the city with the highest fraction of diaspora during the world cup.
## We must also pull from the city's total population (located in B01003_001E). 
## I will write a user-defined function that is generalizable to my tables


def diasporaFraction(code, year):
    call_link = f'https://api.census.gov/data/{year}/acs/acs5'

    census_all_data = []
    for x in code:
        params = {
            'get': f'NAME,{x},B01003_001E',
            'for': 'place:*',
            'key': census_api_key
        }

        ## Format to json data immediately, I think I understand requests.get() well enough
        formatted_response = requests.get(call_link, params=params).json()

        ## Convert to df
        census_formatted_data = pd.DataFrame(formatted_response[1:], columns=formatted_response[0])

        census_formatted_data[x] = pd.to_numeric(census_formatted_data[x], errors='coerce')
        census_formatted_data['B01003_001E'] = pd.to_numeric(census_formatted_data['B01003_001E'], errors='coerce')
        census_formatted_data['frac_diaspora'] = census_formatted_data[x] / census_formatted_data['B01003_001E']
        ## Sort by fraction of diaspora
        census_formatted_data = census_formatted_data.sort_values('frac_diaspora', ascending=False)
        ## Now filter for large cities, I got a result that said Buttzville, NJ contained the highest fraction
        ## of Dutch people. The population of Buttzville is 103.
        census_formatted_data = census_formatted_data[census_formatted_data['B01003_001E'] > 50000].head(1)
        census_all_data.append(census_formatted_data)

    return pd.concat(census_all_data, ignore_index=True)
    
diaspora2022 = diasporaFraction(codes_2022, '2022')

diaspora2024 = diasporaFraction(codes_2024, '2024')

# %%
## Examine datasets to find regions we need to extract from search api

diaspora2022
diaspora2024
# Out:
#                              NAME  B05006_009E  B01003_001E state  place  \
# 0  Laguna Niguel city, California        662.0        64259    06  39248
# 1   Santa Monica city, California          NaN        92168    06  70000
# 2       Glendale city, California          NaN       194512    06  30000
# 3       Horizon West CDP, Florida          NaN        58595    12  32610
#
#    frac_diaspora  B05006_010E  B05006_061E  B05006_018E
# 0       0.010302          NaN          NaN          NaN
# 1       0.007063        651.0          NaN          NaN
# 2       0.138135          NaN      26869.0          NaN
# 3       0.010632          NaN          NaN        623.0
#                             NAME  B05006_175E  B01003_001E state  place  \
# 0           Weston city, Florida        512.0        68837    12  76582
# 1  Santa Monica city, California          NaN        91169    06  70000
# 2       Alpharetta city, Georgia          NaN        66855    13  01696
# 3           Utica city, New York          NaN        64217    36  76540
# 4  Deerfield Beach city, Florida          NaN        88093    12  16725
#
#    frac_diaspora  B05006_132E  B05006_090E  B05006_031E  B05006_015E
# 0       0.007438          NaN          NaN          NaN          NaN
# 1       0.004640        423.0          NaN          NaN          NaN
# 2       0.010605          NaN        709.0          NaN          NaN
# 3       0.039927          NaN          NaN       2564.0          NaN
# 4       0.004030          NaN          NaN          NaN        355.0

# %%
## Now analyze google search trends. I reckon that just selecting keywords will do. I used AI to help me code this part, since I was
## grossly unfamiliar with pytrends. Learning something new!
pytrend = TrendReq()
## Look in the media markets category and just pick the nearest media market to the highest diaspora. Maybe argue that diaspora tend to congregate closely?

## Very weak data with this function, I will have to look into this
def regional_search_interest(cup_windows, resolution='DMA'):
    results = []
    
    for country, windows in cup_windows.items():
        for start, end in windows:
            start_str = str(start)
            end_str = str(end)
            start_fmt = f"{start_str[:4]}-{start_str[4:6]}-{start_str[6:]}"
            end_fmt = f"{end_str[:4]}-{end_str[4:6]}-{end_str[6:]}"
            timeframe = f"{start_fmt} {end_fmt}"
            
            keyword_list = [f"{country.replace('_', ' ')}", f"{country.replace('_', ' ')} soccer"]

            ## This is where I needed help with specifying keyworks, and above with defining the timeline.
            try:
                pytrend.build_payload(kw_list=keyword_list, timeframe=timeframe, geo='US')
                df = pytrend.interest_by_region(resolution=resolution, inc_low_vol=True)
                df = df.reset_index().rename(columns={f"{country.replace('_', ' ')} soccer": "game_search_interest", 
                                             f"{country.replace('_', ' ')}": "country_search_interest"})
                df['country'] = country
                df['window_start'] = start
                df['window_end'] = end
                results.append(df)
            except Exception as e:
                print(f"Error for {country} ({start}-{end}): {e}")
            time.sleep(10)
    
    return pd.concat(results, ignore_index=True)

regional_search_interest_df = regional_search_interest(cup_windows, resolution='DMA')
regional_search_interest_df
# Out:
# Error for Ghana (20140601-20140730): The request failed: Google returned a response with code 429
#                                  geoName  country_search_interest  \
# 0                  Abilene-Sweetwater TX                      100
# 1                              Albany GA                      100
# 2             Albany-Schenectady-Troy NY                       97
# 3                Albuquerque-Santa Fe NM                       97
# 4                          Alexandria LA                      100
# ...                                  ...                      ...
# 2515                       Wilmington NC                      100
# 2516  Yakima-Pasco-Richland-Kennewick WA                       95
# 2517                       Youngstown OH                      100
# 2518                Yuma AZ-El Centro CA                      100
# 2519                       Zanesville OH                      100
#
#       game_search_interest    country  window_start  window_end
# 0                        0  Australia      20260601    20260730
# 1                        0  Australia      20260601    20260730
# 2                        3  Australia      20260601    20260730
# 3                        3  Australia      20260601    20260730
# 4                        0  Australia      20260601    20260730
# ...                    ...        ...           ...         ...
# 2515                     0      Wales      20221101    20221231
# 2516                     5      Wales      20221101    20221231
# 2517                     0      Wales      20221101    20221231
# 2518                     0      Wales      20221101    20221231
# 2519                     0      Wales      20221101    20221231
#
# [2520 rows x 6 columns]

# %%
regional_search_interest_df.to_csv('./data/regional_search_interest.csv', index=False)

# %%
## Part 4: Access sentiment data
## Now simply import and display the the twitter datasets from 2014, 2022.

## Tried converting 2014 file from .txt to .csv but pandas read it weird.
## Instead, read the .txt file as a table
path_to_2014_tweets = "./data/FIFA_2014_sentiment_dataset.txt"
path_to_2022_tweets = "./data/fifa_world_cup_2022_tweets.csv"

## load data
tweets_2014 = pd.read_table(path_to_2014_tweets)
tweets_2014.head()
tweets_2014.info()
## Turns out, this dataset is pretty useless, but good to check anyway. I scoured the internet for anything public/free and could not find anything else
## for the 2014 cup. Unfortunate, but plenty of data from 2022.

tweets_2022 = pd.read_csv(path_to_2022_tweets)
tweets_2022.head()
tweets_2022.info()
# Out:
#    476060286336913408   neutral
# 0  477584843283259392  positive
# 1  478036760815878144  positive
# 2  478021085330673664  positive
# 3  477207573699891200  positive
# 4  477537690028900354  positive
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30067 entries, 0 to 30066
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   476060286336913408  30067 non-null  object
#  1   neutral             30067 non-null  object
# dtypes: object(2)
# memory usage: 469.9+ KB
#    Unnamed: 0               Date Created  Number of Likes  \
# 0           0  2022-11-20 23:59:21+00:00                4
# 1           1  2022-11-20 23:59:01+00:00                3
# 2           2  2022-11-20 23:58:41+00:00                1
# 3           3  2022-11-20 23:58:33+00:00                1
# 4           4  2022-11-20 23:58:28+00:00                0
#
#        Source of Tweet                                              Tweet  \
# 0      Twitter Web App  What are we drinking today @TucanTribe \n@MadB...
# 1   Twitter for iPhone  Amazing @CanadaSoccerEN  #WorldCup2022 launch ...
# 2   Twitter for iPhone  Worth reading while watching #WorldCup2022 htt...
# 3      Twitter Web App  Golden Maknae shinning bright\n\nhttps://t.co/...
# 4  Twitter for Android  If the BBC cares so much about human rights, h...
#
#   Sentiment
# 0   neutral
# 1  positive
# 2  positive
# 3  positive
# 4  negative
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22524 entries, 0 to 22523
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       22524 non-null  int64
#  1   Date Created     22524 non-null  object
#  2   Number of Likes  22524 non-null  int64
#  3   Source of Tweet  22524 non-null  object
#  4   Tweet            22524 non-null  object
#  5   Sentiment        22524 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.0+ MB
