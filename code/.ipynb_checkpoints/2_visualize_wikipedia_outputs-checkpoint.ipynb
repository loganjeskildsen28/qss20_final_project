# %%
## Imports from 1_clean_merge_data.ipynb
import pandas as pd
import numpy as np
import re
import requests
import yaml
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy.optimize import curve_fit
import time

## Set font parameters early
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Times New Roman"]

headers = {
    'User-Agent': 'EskildsenLogan research project (logan.j.eskildsen.28@dartmouth.edu)'
}

## Repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
## Load relevant wikipedia data for visualization
culture_final_df = pd.read_csv('../data/culture_final_data.csv')
football_final_df = pd.read_csv('../data/football_final_data.csv')
country_final_df = pd.read_csv('../data/country_final_data.csv')

## Load relevant search trend data for visualization
regional_final_df = pd.read_csv('../data/regional_final_data.csv')

# %%
## The Wikipedia data I seek to plot is the ratio above mean baseline over time. For the country and football datasets, this is easy.

football_final_df['ratio_to_baseline'] = football_final_df['views'] / football_final_df['mean_views']
football_final_df

country_final_df['ratio_to_baseline'] = country_final_df['views'] / country_final_df['mean_views']
country_final_df

## For the culture dataset, create a new DataFrame that sums the views of all articles over one day and compare to baseline.

culture_final_plot_df = culture_final_df.groupby(['country', 'date'])[['views', 'mean_views']].sum().reset_index().rename(columns={'views': 'total_views', 'mean_views': 'total_mean_views'})
culture_final_plot_df['ratio_to_baseline'] = culture_final_plot_df['total_views'] / culture_final_plot_df['total_mean_views']
# Out:
#      Unnamed: 0.1  Unnamed: 0    country                     article_title  \
# 0               0          10  Australia  Australia National Football Team
# 1               1          11  Australia  Australia National Football Team
# 2               2          12  Australia  Australia National Football Team
# 3               3          13  Australia  Australia National Football Team
# 4               4          14  Australia  Australia National Football Team
# ..            ...         ...        ...                               ...
# 425           425         475     Turkey     Turkey National Football Team
# 426           426         476     Turkey     Turkey National Football Team
# 427           427         477     Turkey     Turkey National Football Team
# 428           428         478     Turkey     Turkey National Football Team
# 429           429         479     Turkey     Turkey National Football Team
#
#          date  views  year  match_date outcome match_type score  \
# 0    20260527     22  2026    20260619     win      group   2-0
# 1    20260528     30  2026    20260619     win      group   2-0
# 2    20260529     29  2026    20260619     win      group   2-0
# 3    20260530    134  2026    20260619     win      group   2-0
# 4    20260531     31  2026    20260619     win      group   2-0
# ..        ...    ...   ...         ...     ...        ...   ...
# 425  20260816   1498  2026    20260625    loss      group   2-3
# 426  20260817   1497  2026    20260625    loss      group   2-3
# 427  20260818   1526  2026    20260625    loss      group   2-3
# 428  20260819   1440  2026    20260625    loss      group   2-3
# 429  20260820   1399  2026    20260625    loss      group   2-3
#
#      score_differential  mean_views   std_views  ratio_to_baseline
# 0                     2        29.7   11.823235           0.740741
# 1                     2        29.7   11.823235           1.010101
# 2                     2        29.7   11.823235           0.976431
# 3                     2        29.7   11.823235           4.511785
# 4                     2        29.7   11.823235           1.043771
# ..                  ...         ...         ...                ...
# 425                  -1      2691.9  289.884057           0.556484
# 426                  -1      2691.9  289.884057           0.556113
# 427                  -1      2691.9  289.884057           0.566886
# 428                  -1      2691.9  289.884057           0.534938
# 429                  -1      2691.9  289.884057           0.519707
#
# [430 rows x 15 columns]
#      Unnamed: 0    country article_title      date  views  year  match_date  \
# 0             0  Australia     Australia  20260527  13894  2026    20260619
# 1             1  Australia     Australia  20260528  14621  2026    20260619
# 2             2  Australia     Australia  20260529  14654  2026    20260619
# 3             3  Australia     Australia  20260530  12149  2026    20260619
# 4             4  Australia     Australia  20260531  12996  2026    20260619
# ..          ...        ...           ...       ...    ...   ...         ...
# 425         425     Turkey        Turkey  20260816  10865  2026    20260625
# 426         426     Turkey        Turkey  20260817  11153  2026    20260625
# 427         427     Turkey        Turkey  20260818  10818  2026    20260625
# 428         428     Turkey        Turkey  20260819  10596  2026    20260625
# 429         429     Turkey        Turkey  20260820  11333  2026    20260625
#
#     outcome match_type score  score_differential  mean_views    std_views  \
# 0       win      group   2-0                   2     14697.3  2335.573308
# 1       win      group   2-0                   2     14697.3  2335.573308
# 2       win      group   2-0                   2     14697.3  2335.573308
# 3       win      group   2-0                   2     14697.3  2335.573308
# 4       win      group   2-0                   2     14697.3  2335.573308
# ..      ...        ...   ...                 ...         ...          ...
# 425    loss      group   2-3                  -1     11430.3   679.246323
# 426    loss      group   2-3                  -1     11430.3   679.246323
# 427    loss      group   2-3                  -1     11430.3   679.246323
# 428    loss      group   2-3                  -1     11430.3   679.246323
# 429    loss      group   2-3                  -1     11430.3   679.246323
#
#      ratio_to_baseline
# 0             0.945344
# 1             0.994809
# 2             0.997054
# 3             0.826614
# 4             0.884244
# ..                 ...
# 425           0.950544
# 426           0.975740
# 427           0.946432
# 428           0.927010
# 429           0.991488
#
# [430 rows x 14 columns]

# %%
## Now calculate mean for each article, sum the means for each country to find baseline for ratio

article_baseline_means = baseline_df.groupby(['country', 'article_title'])['views'].mean().reset_index().rename(columns={'views': 'baseline mean views'})
article_baseline_means
country_baseline_mean = article_baseline_means.groupby('country')['baseline mean views'].sum().reset_index().rename(columns={'baseline_mean_views': 'country baseline mean'})
country_baseline_mean
# Out:
#                    country                                   article_title  \
# 0                Australia                                       Australia
# 1                Australia                           Australian_Government
# 2                Australia             Australian_House_of_Representatives
# 3                Australia                               Bluey_(TV_series)
# 4                Australia                                Graduate_diploma
# 5                  Belgium                                         Belgium
# 6                  Belgium                              Economy_of_Belgium
# 7                  Belgium                                  Flemish_Region
# 8                  Belgium               Hypothetical_partition_of_Belgium
# 9                  Belgium                                     Sinterklaas
# 10                 Belgium                        The_Adventures_of_Tintin
# 11  Bosnia_and_Herzegovina                          Bosnia_and_Herzegovina
# 12  Bosnia_and_Herzegovina               Economy_of_Bosnia_and_Herzegovina
# 13  Bosnia_and_Herzegovina  High_Representative_for_Bosnia_and_Herzegovina
# 14  Bosnia_and_Herzegovina                Template:Campaignbox_Bosnian_War
# 15  Bosnia_and_Herzegovina                         The_Bridge_on_the_Drina
# 16                 England                                          BedZED
# 17                 England                             Counties_of_England
# 18                 England                                         England
# 19                 England                                Northern_England
# 20                 England                                     The_Beatles
# 21                    Iran                                 Economy_of_Iran
# 22                    Iran                                            Iran
# 23                    Iran                                Persian_language
# 24                    Iran                                Politics_of_Iran
# 25                    Iran                          Supreme_Leader_of_Iran
# 26             Netherlands                      Capital_of_the_Netherlands
# 27             Netherlands                    Education_in_the_Netherlands
# 28             Netherlands                                     Netherlands
# 29             Netherlands                     Politics_of_the_Netherlands
# 30             Netherlands                                     Sinterklaas
# 31                Paraguay                 Chamber_of_Deputies_of_Paraguay
# 32                Paraguay                             Culture_of_Paraguay
# 33                Paraguay                                        Mercosur
# 34                Paraguay                                        Paraguay
# 35                Paraguay                           President_of_Paraguay
# 36                  Turkey                             Education_in_Turkey
# 37                  Turkey               Grand_National_Assembly_of_Turkey
# 38                  Turkey                                  Nazar_(amulet)
# 39                  Turkey                             President_of_Turkey
# 40                  Turkey                                          Turkey
# 41                   Wales                                History_of_Wales
# 42                   Wales                                       Mari_Lwyd
# 43                   Wales                                          Senedd
# 44                   Wales                                           Wales
# 45                   Wales                                  Welsh_language
#
#     baseline mean views
# 0          15310.741935
# 1            412.903226
# 2           1075.774194
# 3           4203.935484
# 4            808.645161
# 5           6876.064516
# 6            297.161290
# 7            339.064516
# 8            165.774194
# 9            787.096774
# 10          1680.967742
# 11          4921.225806
# 12           169.225806
# 13           200.870968
# 14             6.833333
# 15           156.032258
# 16            58.161290
# 17          1731.612903
# 18         14679.225806
# 19           609.806452
# 20         22501.483871
# 21           890.096774
# 22         10882.838710
# 23          3531.935484
# 24           197.161290
# 25           674.774194
# 26           187.161290
# 27           556.129032
# 28         13851.838710
# 29           240.935484
# 30           611.709677
# 31            77.645161
# 32            42.000000
# 33          6828.516129
# 34          3605.161290
# 35           159.096774
# 36            97.451613
# 37           588.000000
# 38           792.967742
# 39           494.032258
# 40         12426.096774
# 41           355.903226
# 42           678.096774
# 43           522.806452
# 44          5813.354839
# 45          2563.741935
#                   country  baseline mean views
# 0               Australia         21812.000000
# 1                 Belgium         10146.129032
# 2  Bosnia_and_Herzegovina          5454.188172
# 3                 England         39580.290323
# 4                    Iran         16176.806452
# 5             Netherlands         15447.774194
# 6                Paraguay         10712.419355
# 7                  Turkey         14398.548387
# 8                   Wales          9933.903226

# %%
## Now sum each country's daily views and create a new dataframe 

country_daily_totals = cleaned_wikipedia_df.groupby(['country', 'date'])['views'].sum().reset_index().rename(columns={'views': 'country_daily_total_views'})
country_daily_totals

## Now left join the daily views with the baseline daily views to find a time series for the ratio of views above baseline
country_ratio_df = pd.merge(country_daily_totals, country_baseline_mean, on='country', how='left')
country_ratio_df['views_ratio'] = country_ratio_df['country_daily_total_views'] / country_ratio_df['baseline mean views']
country_ratio_df
# Out:
#        country        date  country_daily_total_views
# 0    Australia  2026-06-01                      19573
# 1    Australia  2026-06-02                      20223
# 2    Australia  2026-06-03                      19099
# 3    Australia  2026-06-04                      20161
# 4    Australia  2026-06-05                      22689
# ..         ...         ...                        ...
# 539      Wales  2022-12-27                      13232
# 540      Wales  2022-12-28                      11510
# 541      Wales  2022-12-29                      11193
# 542      Wales  2022-12-30                      10589
# 543      Wales  2022-12-31                      11976
#
# [544 rows x 3 columns]
#        country        date  country_daily_total_views  baseline mean views  \
# 0    Australia  2026-06-01                      19573         21812.000000
# 1    Australia  2026-06-02                      20223         21812.000000
# 2    Australia  2026-06-03                      19099         21812.000000
# 3    Australia  2026-06-04                      20161         21812.000000
# 4    Australia  2026-06-05                      22689         21812.000000
# ..         ...         ...                        ...                  ...
# 539      Wales  2022-12-27                      13232          9933.903226
# 540      Wales  2022-12-28                      11510          9933.903226
# 541      Wales  2022-12-29                      11193          9933.903226
# 542      Wales  2022-12-30                      10589          9933.903226
# 543      Wales  2022-12-31                      11976          9933.903226
#
#      views_ratio
# 0       0.897350
# 1       0.927150
# 2       0.875619
# 3       0.924308
# 4       1.040207
# ..           ...
# 539     1.332004
# 540     1.158658
# 541     1.126747
# 542     1.065946
# 543     1.205568
#
# [544 rows x 5 columns]

# %%
## Now plot timeseries with fitted decay


match_dates_single = {
    'Australia': pd.Timestamp('2026-06-19'),
    'Belgium': pd.Timestamp('2026-07-06'),
    'Bosnia_and_Herzegovina': pd.Timestamp('2026-07-01'),
    'England': pd.Timestamp('2022-11-25'),
    'Iran': pd.Timestamp('2022-11-29'),
    'Netherlands': pd.Timestamp('2022-12-03'),
    'Paraguay': pd.Timestamp('2026-06-12'),
    'Turkey': pd.Timestamp('2026-06-25'),
    'Wales': pd.Timestamp('2022-11-21'),
}

countries = list(match_dates_single.keys())

## Ensure date column is real datetime, once, up front
country_ratio_df['date'] = pd.to_datetime(country_ratio_df['date'])

fig, axes = plt.subplots(3, 3, figsize=(18, 14))
axes = axes.flatten()

A = None

def decay_func(t, lam):
    return (A - 1) * np.exp(-lam * t) + 1

fit_results = []

for ax, country in zip(axes, countries):
    match_date = match_dates_single[country]
    
    ## Filter to just this country's data — this was missing
    test_d = country_ratio_df[country_ratio_df['country'] == country].sort_values('date').copy()
    
    if test_d.empty:
        ax.set_title(f"{country} (no data)", fontsize=12)
        continue

    ## Now define a window that tests if there is a nearby maximum from the match date

    
    ## Isolate data from the match date onward, for THIS country only
    post_match = test_d[test_d['date'] >= match_date].copy()
    post_match['days_since_match'] = (post_match['date'] - match_date).dt.days

    peak_window = post_match[(post_match['days_since_match'] >= 0) & (post_match['days_since_match'] <= 2)]

    if not peak_window.empty:
        peak_row = peak_window.loc[peak_window['views_ratio'].idxmax()]
        A = peak_row['views_ratio']
        peak_ratio_date = peak_row['days_since_match']
    else:
        A = post_match['views_ratio'].iloc[0]
        peak_ratio_date = 0

    fitted_window = post_match[(post_match['days_since_match'] >= peak_ratio_date) & (post_match['days_since_match'] <= 20)].copy()
    fitted_window['t_since_peak'] = fitted_window['days_since_match'] - peak_ratio_date

    try:
        p0 = [0.2]
        params, pcov = curve_fit(decay_func, fitted_window['t_since_peak'], fitted_window['views_ratio'],
                              p0=p0, sigma=fitted_window['views_ratio'], maxfev=10000)
        lam_fit = params[0]
        fitted_curve = decay_func(fitted_window['t_since_peak'], lam_fit)
        half_life = np.log(2) / lam_fit

        se_lam = np.sqrt(np.diag(pcov))[0]
        se_half_life = se_lam * np.log(2) / (lam_fit ** 2)
        ss_res = np.sum((fitted_window['views_ratio'] - fitted_curve) ** 2)
        ss_tot = np.sum((fitted_window['views_ratio'] - fitted_window['views_ratio'].mean()) ** 2)
        r_squared = 1 - ss_res / ss_tot

        fit_label = f'Fitted decay (half-life ≈ {half_life:.1f}d)'
        fit_success = True

        fit_results.append({
        'country': country, 'peak_ratio': A, 'peak_day_since_match': peak_ratio_date,
        'lambda': lam_fit, 'lambda_se': se_lam,
        'half_life_days': half_life, 'half_life_se': se_half_life,
        'r_squared': r_squared, 'n_points_fit': len(fitted_window)
        })
    except Exception as e:
        print(f"Curve fit failed for {country}: {e}")
        fit_success = False
        fit_results.append({
        'country': country, 'peak_ratio': A, 'peak_day_since_match': peak_ratio_date,
        'lambda': np.nan, 'lambda_se': np.nan, 'half_life_days': np.nan,
        'half_life_se': np.nan, 'r_squared': np.nan, 'n_points_fit': len(fitted_window)
        })
    
    ## Plot raw data for THIS country only
    ax.plot(test_d['date'], test_d['views_ratio'], color='#0BBBBB', linewidth=1.5)
    
    if fit_success:
        ax.plot(fitted_window['date'], fitted_curve, color='#333333', linewidth=1.8,
                linestyle='--', label=fit_label)
        ax.legend(fontsize=8)
    
    ax.set_title(country.replace('_', ' '), fontsize=13, fontweight='bold')
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=6))
    ax.tick_params(axis='x', rotation=45, labelsize=8)
    ax.tick_params(axis='y', labelsize=8)
    
    ## y-axis scaled to THIS country's own max, not the global max
    ax.set_ylim(1, max(test_d['views_ratio']) * 1.1)
    
    ax.grid(axis='y', alpha=0.3, linestyle='--')
    ax.axvline(match_date, color='red', linestyle=':', alpha=0.6)

fig.suptitle("Wikipedia Daily Views: Ratio to Baseline by Country", fontsize=18, fontweight='bold', y=1.02)
fig.supxlabel("Date", fontsize=14)
fig.supylabel("Ratio to Baseline Views", fontsize=14)

plt.tight_layout()
fig.savefig('../outputs/wikipedia_timeseries_grid.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Text(0.5, 1.0, 'Australia')
# (1.0, 1.832862644415918)
# Text(0.5, 1.0, 'Belgium')
# (1.0, 13.461114043175533)
# Text(0.5, 1.0, 'Bosnia and Herzegovina')
# (1.0, 62.31908201155471)
# Text(0.5, 1.0, 'England')
# (1.0, 3.048072639608016)
# Text(0.5, 1.0, 'Iran')
# (1.0, 6.509640843820604)
# Text(0.5, 1.0, 'Netherlands')
# (1.0, 6.6730843361920815)
# Text(0.5, 1.0, 'Paraguay')
# (1.0, 12.378828312028547)
# Text(0.5, 1.0, 'Turkey')
# (1.0, 4.480889202540579)
# Text(0.5, 1.0, 'Wales')
# (1.0, 27.133523839831664)
# Text(0.5, 1.02, 'Wikipedia Daily Views: Ratio to Baseline by Country')
# Text(0.5, 0.01, 'Date')
# Text(0.02, 0.5, 'Ratio to Baseline Views')

# %%
pd.DataFrame(fit_results)
# Out:
#                   country  peak_ratio  peak_day_since_match    lambda  \
# 0               Australia    1.528150                     0  0.094451
# 1                 Belgium   12.237376                     1  1.845995
# 2  Bosnia_and_Herzegovina   56.653711                     1  2.074587
# 3                 England    1.914463                     0  1.655691
# 4                    Iran    5.469065                     0  0.727529
# 5             Netherlands    6.066440                     0  0.354308
# 6                Paraguay    8.263679                     1  7.292568
# 7                  Turkey    4.073536                     1  2.982283
# 8                   Wales   24.666840                     0  0.953124
#
#     lambda_se  half_life_days  half_life_se  r_squared  n_points_fit
# 0    0.020002        7.338713      1.554097  -0.709528            21
# 1    0.327198        0.375487      0.066554   0.820634            20
# 2    0.352248        0.334113      0.056730   0.992722            20
# 3    1.033021        0.418645      0.261202   0.349863            21
# 4    0.134078        0.952741      0.175583   0.821815            21
# 5    0.054926        1.956343      0.303279   0.431139            21
# 6  107.256168        0.095048      1.397934   0.106189            20
# 7    0.961980        0.232422      0.074971   0.918512            20
# 8    0.200915        0.727237      0.153299   0.588237            21
